# %%
import pandas as pd
import tqdm

from utils import MetricHelper, InferenceHelper, PromptHelper

# %%
df = pd.read_csv('Data_FailureFixExplanation.csv')
ref_df = pd.read_csv('Root_Cause_Ref.csv')

# %%
default_df = InferenceHelper.generateExplanationsWithMetrics(df, ref_df, mode='default')

# %%
source_df = InferenceHelper.generateExplanationsWithMetrics(df, ref_df, mode='source')

# %%
test_df = InferenceHelper.generateExplanationsWithMetrics(df, ref_df, mode='error')

# %%
oneshot_df = InferenceHelper.generateExplanationsWithMetrics(df, ref_df, mode='oneshot')
# Out:
# INFO:tensorflow:Reading checkpoint BLEURT-20.
# INFO:tensorflow:Config file found, reading.
# INFO:tensorflow:Will load checkpoint BLEURT-20
# INFO:tensorflow:Loads full paths and checks that files exists.
# INFO:tensorflow:... name:BLEURT-20
# INFO:tensorflow:... bert_config_file:bert_config.json
# INFO:tensorflow:... max_seq_length:512
# INFO:tensorflow:... vocab_file:None
# INFO:tensorflow:... do_lower_case:None
# INFO:tensorflow:... sp_model:sent_piece
# INFO:tensorflow:... dynamic_seq_length:True
# INFO:tensorflow:Creating BLEURT scorer.
# INFO:tensorflow:Creating SentencePiece tokenizer.
# INFO:tensorflow:Creating SentencePiece tokenizer.
# INFO:tensorflow:Will load model: BLEURT-20/sent_piece.model.
# INFO:tensorflow:SentencePiece tokenizer created.
# INFO:tensorflow:Creating Eager Mode predictor.
# INFO:tensorflow:Loading model.
# INFO:tensorflow:BLEURT initialized.
# INFO:tensorflow:BLEURT initialized.
# INFO:tensorflow:Average batch sequence length: 208.0
# ...

# %%
oneshot_df
# Out:
#                                                 explanation  \
# HIT01_8   The root cause of the bug is related to line 2...
# HIT02_24  The root cause of the software failure can be ...
# HIT03_6   The root cause of the bug is due to an issue i...
# HIT04_7   The root cause for the thrown exception is an ...
# HIT05_35  The error is caused by defaulting to the Objec...
# HIT06_51  The issue lies at line 260 where the 'add(Long...
# HIT07_33  The root cause of the software failure is that...
# HIT08_54  The input string with the format "fr__POSIX" d...
#
#                                               description_c  \
# HIT01_8   The root cause for the thrown exception is in ...
# HIT02_24  The root cause for the thrown exception is in ...
# HIT03_6   The root cause for the thrown exception is in ...
# HIT04_7   The root cause for the thrown exception is in ...
# HIT05_35  The root cause for the thrown error is in line...
# HIT06_51  The root cause for the thrown exception is in ...
# ...

# %%
modes = ['default', 'source', 'error', 'oneshot']
# models = ['deepseek-llm:7b', 'llama3.2:3b', 'codellama:13b', 'deepseek-coder-v2:16b', 'codellama:13b-instruct-q4_K_S']
models = ['deepseek-llm:7b', 'llama3.2:3b', 'codellama:13b']
settings = {
    'deepseek-llm:7b': {
        'context_limit': 24576,
        'predict_limit': 8192
    }
}

# %%
# explanations = df[(df['File'] == 'HIT01_8')]['Explanation'].to_list()
# prompt = InferenceHelper.generatePrompt(explanations, 'HIT01_8', 'source', df, ref_df)
# response = InferenceHelper.runInference(prompt, model='deepseek-coder-v2:16b', context_limit=24576, predict_limit=8192, gpu_layers=20)
# response

# %%
for model in models:
    for mode in modes:
        InferenceHelper.generateExplanationsWithMetrics(df, ref_df, model=model, mode=mode, context_limit=4096, predict_limit=4096)
# Out:
# 100%|██████████| 8/8 [00:27<00:00,  3.48s/it]
# INFO:tensorflow:Reading checkpoint BLEURT-20.
# INFO:tensorflow:Reading checkpoint BLEURT-20.
# INFO:tensorflow:Config file found, reading.
# INFO:tensorflow:Config file found, reading.
# INFO:tensorflow:Will load checkpoint BLEURT-20
# INFO:tensorflow:Will load checkpoint BLEURT-20
# INFO:tensorflow:Loads full paths and checks that files exists.
# INFO:tensorflow:Loads full paths and checks that files exists.
# INFO:tensorflow:... name:BLEURT-20
# INFO:tensorflow:... name:BLEURT-20
# INFO:tensorflow:... bert_config_file:bert_config.json
# INFO:tensorflow:... bert_config_file:bert_config.json
# INFO:tensorflow:... max_seq_length:512
# INFO:tensorflow:... max_seq_length:512
# INFO:tensorflow:... vocab_file:None
# INFO:tensorflow:... vocab_file:None
# INFO:tensorflow:... do_lower_case:None
# INFO:tensorflow:... do_lower_case:None
# INFO:tensorflow:... sp_model:sent_piece
# INFO:tensorflow:... sp_model:sent_piece
# ...

# %%
for mode in modes:
        InferenceHelper.generateExplanationsWithMetrics(df, ref_df, model='deepseek-coder-v2:16b', mode=mode, context_limit=24576, predict_limit=8192)
# Out:
# 100%|██████████| 8/8 [01:31<00:00, 11.39s/it]
# INFO:tensorflow:Reading checkpoint BLEURT-20.
# INFO:tensorflow:Reading checkpoint BLEURT-20.
# INFO:tensorflow:Config file found, reading.
# INFO:tensorflow:Config file found, reading.
# INFO:tensorflow:Will load checkpoint BLEURT-20
# INFO:tensorflow:Will load checkpoint BLEURT-20
# INFO:tensorflow:Loads full paths and checks that files exists.
# INFO:tensorflow:Loads full paths and checks that files exists.
# INFO:tensorflow:... name:BLEURT-20
# INFO:tensorflow:... name:BLEURT-20
# INFO:tensorflow:... bert_config_file:bert_config.json
# INFO:tensorflow:... bert_config_file:bert_config.json
# INFO:tensorflow:... max_seq_length:512
# INFO:tensorflow:... max_seq_length:512
# INFO:tensorflow:... vocab_file:None
# INFO:tensorflow:... vocab_file:None
# INFO:tensorflow:... do_lower_case:None
# INFO:tensorflow:... do_lower_case:None
# INFO:tensorflow:... sp_model:sent_piece
# INFO:tensorflow:... sp_model:sent_piece
# ...

# %%
for mode in modes:
        InferenceHelper.generateExplanationsWithMetrics(df, ref_df, model='codellama:13b-instruct-q4_K_S', mode=mode, context_limit=4096, predict_limit=4096)
# Out:
# 100%|██████████| 8/8 [01:42<00:00, 12.78s/it]
# INFO:tensorflow:Reading checkpoint BLEURT-20.
# INFO:tensorflow:Reading checkpoint BLEURT-20.
# INFO:tensorflow:Config file found, reading.
# INFO:tensorflow:Config file found, reading.
# INFO:tensorflow:Will load checkpoint BLEURT-20
# INFO:tensorflow:Will load checkpoint BLEURT-20
# INFO:tensorflow:Loads full paths and checks that files exists.
# INFO:tensorflow:Loads full paths and checks that files exists.
# INFO:tensorflow:... name:BLEURT-20
# INFO:tensorflow:... name:BLEURT-20
# INFO:tensorflow:... bert_config_file:bert_config.json
# INFO:tensorflow:... bert_config_file:bert_config.json
# INFO:tensorflow:... max_seq_length:512
# INFO:tensorflow:... max_seq_length:512
# INFO:tensorflow:... vocab_file:None
# INFO:tensorflow:... vocab_file:None
# INFO:tensorflow:... do_lower_case:None
# INFO:tensorflow:... do_lower_case:None
# INFO:tensorflow:... sp_model:sent_piece
# INFO:tensorflow:... sp_model:sent_piece
# ...

# %%
for mode in modes:
        InferenceHelper.generateExplanationsWithMetrics(df, ref_df, model='llama3.2:3b-instruct-q6_K', mode=mode, context_limit=4096, predict_limit=4096)
# Out:
# 100%|██████████| 8/8 [00:28<00:00,  3.56s/it]
# INFO:tensorflow:Reading checkpoint BLEURT-20.
# INFO:tensorflow:Reading checkpoint BLEURT-20.
# INFO:tensorflow:Config file found, reading.
# INFO:tensorflow:Config file found, reading.
# INFO:tensorflow:Will load checkpoint BLEURT-20
# INFO:tensorflow:Will load checkpoint BLEURT-20
# INFO:tensorflow:Loads full paths and checks that files exists.
# INFO:tensorflow:Loads full paths and checks that files exists.
# INFO:tensorflow:... name:BLEURT-20
# INFO:tensorflow:... name:BLEURT-20
# INFO:tensorflow:... bert_config_file:bert_config.json
# INFO:tensorflow:... bert_config_file:bert_config.json
# INFO:tensorflow:... max_seq_length:512
# INFO:tensorflow:... max_seq_length:512
# INFO:tensorflow:... vocab_file:None
# INFO:tensorflow:... vocab_file:None
# INFO:tensorflow:... do_lower_case:None
# INFO:tensorflow:... do_lower_case:None
# INFO:tensorflow:... sp_model:sent_piece
# INFO:tensorflow:... sp_model:sent_piece
# ...
